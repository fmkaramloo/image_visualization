# %%
import json
import PIL
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import urllib

# %%
PIL.__version__
# Out:
# '6.2.0'

# %%
xy = [199.84, 200.46, 77.71, 70.88]

# %%
# ImageDraw.draw_rectangle(xy, fill=None, outline=None, width=1)
# d = ImageDraw.Draw(image)
# # d.multiline_text((10,10), "Mitra", font=fnt, fill=(0, 0, 0))
# d.multiline_text((10,10), "Mitra", fill=(0, 0, 0))

# %%
def annotate_image(image_file, xy):
    im = Image.open(image_file)
    xy2 = [xy[0], xy[1]]
    xy3 = [xy[2], xy[3]]
#     display(xy)
    if xy2[0]>xy3[0]:
        xy_a = xy3
        width = xy2[0] - xy3[0]
        height = xy2[1] - xy3[1]
    else:
        xy_a = xy2
        width = xy3[0] - xy2[0]
        height = xy3[1] - xy2[1]
    # Create figure and axes
    fig, ax = plt.subplots()

    # Display the image
    ax.imshow(im)

    # Create a Rectangle patch
    rect = patches.Rectangle(tuple(xy_a), width, height, linewidth=1, edgecolor='r', facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)
    plt.axis('off')
    plt.show()

# %%
def annotate_image2(image_file, xy):
    im = Image.open(image_file)
    # Create figure and axes
    fig, ax = plt.subplots()

    # Display the image
    ax.imshow(im)

    for xy1 in xy:
        xscale= 0.531
        yscale=0.638
        xy2 = [xy1[0]*xscale, xy1[1]*yscale]
        xy3 = [xy1[2]*xscale, xy1[3]*yscale]
        xy_a = xy2
        width = (xy2[0] - xy3[0])
        height = xy2[1] - xy3[1]
#                 0.638
# 0.531

    #     display(xy)
#         if xy2[0]>xy3[0]:
#             xy_a = xy3
#             width = xy2[0] - xy3[0]
#             height = xy2[1] - xy3[1]
#         else:
#             xy_a = xy2
#             width = xy3[0] - xy2[0]
#             height = xy3[1] - xy2[1]

        # Create a Rectangle patch
        rect = patches.Rectangle(tuple(xy_a), width, height, linewidth=1, edgecolor='r', facecolor='none')

        # Add the patch to the Axes
        ax.add_patch(rect)
    plt.axis('off')
    plt.show()

# %%
annotate_image('images/COCO_val2014_000000558840.jpg', [199.84, 200.46, 77.71, 70.88])

# %%
annotate_image2('images/COCO_val2014_000000391895.jpg', [[359.17, 146.17, 112.45, 213.57],
  [339.88, 22.16, 153.88, 300.73],
  [471.64, 172.82, 35.92, 48.1],
  [486.01, 183.31, 30.63, 34.98]])

# %%
all_images[0]
# Out:
# {'license': 3,
#  'file_name': 'COCO_val2014_000000391895.jpg',
#  'coco_url': 'http://images.cocodataset.org/val2014/COCO_val2014_000000391895.jpg',
#  'height': 360,
#  'width': 640,
#  'date_captured': '2013-11-14 11:18:45',
#  'flickr_url': 'http://farm9.staticflickr.com/8186/8119368305_4e622c8349_z.jpg',
#  'id': 391895,
#  'bboxes': [[359.17, 146.17, 112.45, 213.57],
#   [339.88, 22.16, 153.88, 300.73],
#   [471.64, 172.82, 35.92, 48.1],
#   [486.01, 183.31, 30.63, 34.98]]}

# %%
counter = 0
for img in all_images:
    if counter >= 100:
        break
    counter +=1
    image_url = img["coco_url"]
    image_name = image_url.split("/")[-1]
    download = urllib.request.URLopener()
    download.retrieve(image_url, "images/"+image_name)
    
image_url, image_name
# Out:
# ('http://images.cocodataset.org/val2014/COCO_val2014_000000032907.jpg',
#  'COCO_val2014_000000032907.jpg')

# %%
# display(image)

# %%
# !pip install Pillow

# %%
with open('annotations/instances_val2014.json') as f:
    data = json.load(f)

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
print(data.keys())
# Out:
# dict_keys(['info', 'images', 'licenses', 'annotations', 'categories'])

# %%
bboxes = {}
for x in data['annotations']:
    if x["image_id"] not in bboxes:
        bboxes[x["image_id"]] = []
    bboxes[x["image_id"]].append(x["bbox"])

# %%
len(bboxes[391895])
# Out:
# 4

# %%
all_images = []

for item in data['images']:
    image_id = int(item["id"])
    if image_id in bboxes:
        #print(image_id)
        item["bboxes"] = bboxes[image_id]
        all_images.append(item)

# %%
all_images2 = []

for item in data['images']:
    d = {"coco_url": item["coco_url"]}
    image_id = int(item["id"])
    if image_id in bboxes:
        #print(image_id)
        d["bboxes"] = bboxes[image_id]
        all_images2.append(d)

# %%
all_images[0]
# Out:
# {'license': 3,
#  'file_name': 'COCO_val2014_000000391895.jpg',
#  'coco_url': 'http://images.cocodataset.org/val2014/COCO_val2014_000000391895.jpg',
#  'height': 360,
#  'width': 640,
#  'date_captured': '2013-11-14 11:18:45',
#  'flickr_url': 'http://farm9.staticflickr.com/8186/8119368305_4e622c8349_z.jpg',
#  'id': 391895,
#  'bboxes': [[359.17, 146.17, 112.45, 213.57],
#   [339.88, 22.16, 153.88, 300.73],
#   [471.64, 172.82, 35.92, 48.1],
#   [486.01, 183.31, 30.63, 34.98]]}

# %%
all_images2[0]
# Out:
# {'coco_url': 'http://images.cocodataset.org/val2014/COCO_val2014_000000391895.jpg',
#  'bboxes': [[359.17, 146.17, 112.45, 213.57],
#   [339.88, 22.16, 153.88, 300.73],
#   [471.64, 172.82, 35.92, 48.1],
#   [486.01, 183.31, 30.63, 34.98]]}

# %%
data["images"][0]
# Out:
# {'license': 3,
#  'file_name': 'COCO_val2014_000000391895.jpg',
#  'coco_url': 'http://images.cocodataset.org/val2014/COCO_val2014_000000391895.jpg',
#  'height': 360,
#  'width': 640,
#  'date_captured': '2013-11-14 11:18:45',
#  'flickr_url': 'http://farm9.staticflickr.com/8186/8119368305_4e622c8349_z.jpg',
#  'id': 391895}

# %%
# images[391895] = 'http://images.cocodataset.org/val2014/COCO_val2014_000000391895.jpg'

# %%
images = {}
for item in data['images']:
    images[item["id"]] = item["coco_url"]

# %%
## Me:
annotations = []

for x in data['annotations']:
    tid = int(x["id"])
    if tid in bboxes:
        #print(tid)
        x["coco_url"] = bboxes[tid]
        annotations.append(x)

# %%
print (annotations[:5])
# Out:
# [{'segmentation': [[239.97, 260.24, 222.04, 270.49, 199.84, 253.41, 213.5, 227.79, 259.62, 200.46, 274.13, 202.17, 277.55, 210.71, 249.37, 253.41, 237.41, 264.51, 242.54, 261.95, 228.87, 271.34]], 'area': 2765.1486500000005, 'iscrowd': 0, 'image_id': 558840, 'bbox': [199.84, 200.46, 77.71, 70.88], 'category_id': 58, 'id': 156, 'coco_url': [199.84, 200.46, 77.71, 70.88]}, {'segmentation': [[247.71, 354.7, 253.49, 346.99, 276.63, 337.35, 312.29, 333.49, 364.34, 331.57, 354.7, 327.71, 369.16, 325.78, 376.87, 333.49, 383.61, 330.6, 379.76, 321.93, 365.3, 320.0, 356.63, 317.11, 266.02, 331.57, 260.24, 334.46, 260.24, 337.35, 242.89, 338.31, 234.22, 338.31, 234.22, 348.92, 239.04, 353.73, 248.67, 355.66, 252.53, 353.73]], 'area': 1545.4213000000007, 'iscrowd': 0, 'image_id': 200365, 'bbox': [234.22, 317.11, 149.39, 38.55], 'category_id': 58, 'id': 509, 'coco_url': [234.22, 317.11, 149.39, 38.55]}, {'segmentation': [[274.58, 405.68, 298.32, 405.68, 302.45, 402.58, 333.42, 404.65, 356.13, 397.42, 386.06, 386.06, 398.45, 367.48, 399.48, 356.13, 392.26, 347.87, 382.97, 350.97, 339.61, 357.16, 283.87, 365.42, 269.42, 367.48, 243.61, 362.32, 239.48, 368.52, 241.55, 374.71, 253.94, 381.94, 267.35, 385.03, 271.48, 394.32, 271.48, 399.48, 272.52, 400.52, 281.81, 404.65]], 'area': 5607.661349999996, 'iscrowd': 0, 'image_id': 200365, 'bbox': [239.48, 347.87, 160.0, 57.81], 'category_id': 58, 'id': 603, 'coco_url': [239.48, 347.87, 160.0, 57.81]}, {'segmentation': [[296.65, 388.33, 296.65, 388.33, 297.68, 388.33, 297.68, 388.33]], 'area': 0.0, 'iscrowd': 0, 'image_id': 200365, 'bbox': [296.65, 388.33, 1.03, 0.0], 'category_id': 58, 'id': 918, 'coco_url': [296.65, 388.33, 1.03, 0.0]}, {'segmentation': [[251.87, 356.13, 260.13, 343.74, 300.39, 335.48, 323.1, 335.48, 340.65, 335.48, 366.45, 334.45, 377.81, 333.42, 359.23, 337.55, 332.39, 340.65, 300.39, 346.84, 267.35, 349.94, 252.9, 355.1, 252.9, 355.1]], 'area': 800.4132499999978, 'iscrowd': 0, 'image_id': 200365, 'bbox': [251.87, 333.42, 125.94, 22.71], 'category_id': 58, 'id': 1072, 'coco_url': [251.87, 333.42, 125.94, 22.71]}]

# %%
type(data["annotations"])
# Out:
# list

# %%
data['annotations'][0]
# Out:
# {'segmentation': [[239.97,
#    260.24,
#    222.04,
#    270.49,
#    199.84,
#    253.41,
#    213.5,
#    227.79,
#    259.62,
#    200.46,
#    274.13,
#    202.17,
#    277.55,
#    210.71,
#    249.37,
#    253.41,
#    237.41,
#    264.51,
#    242.54,
#    261.95,
#    228.87,
#    271.34]],
#  'area': 2765.1486500000005,
#  'iscrowd': 0,
#  'image_id': 558840,
#  'bbox': [199.84, 200.46, 77.71, 70.88],
#  'category_id': 58,
#  'id': 156}

# %%
annotations = []

for item in data['annotations']:
    image_id = int(item["image_id"])
    if image_id in images:
        #print(image_id)
        item["coco_url"] = images[image_id]
        annotations.append(item)

# %%
len(data['images']), len(data['annotations']), len(annotations)
# Out:
# (40504, 291875, 291875)

# %%
len(data['images']), len(data['annotations']), len(annotations)
# Out:
# (40504, 291875, 291875)

# %%
print(data['images'][0].keys())
# Out:
# dict_keys(['license', 'file_name', 'coco_url', 'height', 'width', 'date_captured', 'flickr_url', 'id'])

# %%
print(data['annotations'][0])
# Out:
# {'segmentation': [[239.97, 260.24, 222.04, 270.49, 199.84, 253.41, 213.5, 227.79, 259.62, 200.46, 274.13, 202.17, 277.55, 210.71, 249.37, 253.41, 237.41, 264.51, 242.54, 261.95, 228.87, 271.34]], 'area': 2765.1486500000005, 'iscrowd': 0, 'image_id': 558840, 'bbox': [199.84, 200.46, 77.71, 70.88], 'category_id': 58, 'id': 156}

# %%
print(data["annotations"][0].keys())
# Out:
# dict_keys(['segmentation', 'area', 'iscrowd', 'image_id', 'bbox', 'category_id', 'id', 'coco_url'])

# %%
print(json.dumps(data["annotations"][0], indent=4))
# Out:
# {
#     "segmentation": [
#         [
#             239.97,
#             260.24,
#             222.04,
#             270.49,
#             199.84,
#             253.41,
#             213.5,
#             227.79,
#             259.62,
#             200.46,
#             274.13,
#             202.17,
#             277.55,
#             210.71,
#             249.37,
#             253.41,
#             237.41,
#             264.51,
#             242.54,
#             261.95,
#             228.87,
#             271.34
#         ]
#     ],
#     "area": 2765.1486500000005,
#     "iscrowd": 0,
#     "image_id": 558840,
#     "bbox": [
#         199.84,
#         200.46,
#         77.71,
#         70.88
#     ],
#     "category_id": 58,
#     "id": 156
# }

# %%
print(type(data["annotations"]))
# Out:
# <class 'list'>

# %%
print(type(data["annotations"][0].keys()))
# Out:
# <class 'dict_keys'>

# %%
print(type(data["annotations"][0]["bbox"]))
# Out:
# <class 'list'>

# %%
print(data["annotations"][0]["bbox"])
# Out:
# [199.84, 200.46, 77.71, 70.88]
