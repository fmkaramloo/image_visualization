# %%
import json
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import urllib
from pathlib import Path

# %%
def annotate_image(image_file, xy):
    im = Image.open(image_file)
    # Create figure and axes
    fig, ax = plt.subplots()

    # Display the image
    ax.imshow(im)

    for XY in xy:
        cat = XY[1]
        XY = XY[0]

        x1 = XY[0]
        width = XY[2]
        y1 = XY[1]
        height = XY[3]

        rect = patches.Rectangle([x1, y1], width, height, linewidth=1, edgecolor='r', facecolor='none')

        # Add the patch to the Axes
        ax.add_patch(rect)
        ax.text(x1, y1+16, all_categories.loc[cat]["name"], color="yellow", bbox=dict(facecolor='red', alpha=0.2))
    plt.axis('off')
    plt.savefig("bboxes/"+image_file, bbox_inches="tight", pad_inches=0)
    plt.show()

# %%
xy = [
    [[359.17, 146.17, 112.45, 213.57], 4],
    [[339.88, 22.16, 153.88, 300.73], 1],
    [[471.64, 172.82, 35.92, 48.1], 1],
    [[486.01, 183.31, 30.63, 34.98], 2]
]

image_file = "images/COCO_val2014_000000391895.jpg"
annotate_image(image_file, xy)

# %%
with open('annotations/instances_val2014.json') as f:
    data = json.load(f)

# %%
data['annotations'][0]
# Out:
# {'segmentation': [[239.97,
#    260.24,
#    222.04,
#    270.49,
#    199.84,
#    253.41,
#    213.5,
#    227.79,
#    259.62,
#    200.46,
#    274.13,
#    202.17,
#    277.55,
#    210.71,
#    249.37,
#    253.41,
#    237.41,
#    264.51,
#    242.54,
#    261.95,
#    228.87,
#    271.34]],
#  'area': 2765.1486500000005,
#  'iscrowd': 0,
#  'image_id': 558840,
#  'bbox': [199.84, 200.46, 77.71, 70.88],
#  'category_id': 58,
#  'id': 156}

# %%
len(data['images']), len(data['annotations'])
# Out:
# (40504, 291875)

# %%
data['annotations'][0]
# Out:
# {'segmentation': [[239.97,
#    260.24,
#    222.04,
#    270.49,
#    199.84,
#    253.41,
#    213.5,
#    227.79,
#    259.62,
#    200.46,
#    274.13,
#    202.17,
#    277.55,
#    210.71,
#    249.37,
#    253.41,
#    237.41,
#    264.51,
#    242.54,
#    261.95,
#    228.87,
#    271.34]],
#  'area': 2765.1486500000005,
#  'iscrowd': 0,
#  'image_id': 558840,
#  'bbox': [199.84, 200.46, 77.71, 70.88],
#  'category_id': 58,
#  'id': 156}

# %%
bboxes = {}
category = {}
for item in data['annotations']:
    if item["image_id"] not in bboxes:
        bboxes[item["image_id"]] = []
    bboxes[item["image_id"]].append([item["bbox"], item["category_id"]])

# %%
len(bboxes[558840]), bboxes[558840]
# Out:
# (11,
#  [[[199.84, 200.46, 77.71, 70.88], 58],
#   [[325.27, 104.38, 33.67, 105.99], 44],
#   [[168.85, 90.98, 31.42, 88.73], 44],
#   [[1.92, 87.91, 34.95, 175.35], 47],
#   [[346.58, 1.07, 292.01, 343.71], 1],
#   [[239.08, 42.72, 19.88, 76.73], 44],
#   [[409.93, 215.42, 71.84, 50.12], 50],
#   [[0.96, 1.02, 93.08, 160.25], 1],
#   [[276.39, 13.81, 31.75, 61.57], 44],
#   [[3.33, 263.96, 359.34, 156.39], 67],
#   [[413.54, 201.9, 72.79, 56.38], 50]])

# %%
all_categories = pd.DataFrame(data['categories']).set_index("id")
all_categories.loc[58]["name"]
# Out:
# 'hot dog'

# %%
bboxes[558840]
# Out:
# [[[199.84, 200.46, 77.71, 70.88], 58],
#  [[325.27, 104.38, 33.67, 105.99], 44],
#  [[168.85, 90.98, 31.42, 88.73], 44],
#  [[1.92, 87.91, 34.95, 175.35], 47],
#  [[346.58, 1.07, 292.01, 343.71], 1],
#  [[239.08, 42.72, 19.88, 76.73], 44],
#  [[409.93, 215.42, 71.84, 50.12], 50],
#  [[0.96, 1.02, 93.08, 160.25], 1],
#  [[276.39, 13.81, 31.75, 61.57], 44],
#  [[3.33, 263.96, 359.34, 156.39], 67],
#  [[413.54, 201.9, 72.79, 56.38], 50]]

# %%
all_images = []

for image in data['images']:
    
    # for every image in the "images" key, we will extarct "coco_url" and add it to a "new_dictionary"
    new_dictionary = {}
    new_dictionary["coco_url"] = image["coco_url"]
    image_id = int(image["id"])
    
    if image_id in bboxes:
        
        # Add the "bboxes" for the "image_id" to the "new_dictionary"
        new_dictionary["bboxes"] = bboxes[image_id]
        
        # add the image path to the "new_dictionary" by spliting the image url and take the last index in the splitted list
        new_dictionary["image_path"] = "images/" + new_dictionary["coco_url"].split("/")[-1]
        
        # Append the "new_dictionary" to "all_images" list
        all_images.append(new_dictionary)

# %%
len(all_images)
# Out:
# 40137

# %%
all_images[0]
# Out:
# {'coco_url': 'http://images.cocodataset.org/val2014/COCO_val2014_000000391895.jpg',
#  'bboxes': [[[359.17, 146.17, 112.45, 213.57], 4],
#   [[339.88, 22.16, 153.88, 300.73], 1],
#   [[471.64, 172.82, 35.92, 48.1], 1],
#   [[486.01, 183.31, 30.63, 34.98], 2]],
#  'image_path': 'images/COCO_val2014_000000391895.jpg'}

# %%
downloaded_images = []
counter = 0
for img in all_images:
    if counter >= 10:
        break
    counter +=1
    image_url = img["coco_url"]
    download = urllib.request.URLopener()
    if not Path(img["image_path"]).is_file():
        print("Downloading... " + img["image_path"])
        download.retrieve(image_url, img["image_path"])
    downloaded_images.append(img)

# %%
for x in downloaded_images:
    annotate_image(x["image_path"], x["bboxes"])

# %%
data.keys()
# Out:
# dict_keys(['info', 'images', 'licenses', 'annotations', 'categories'])

# %%
import pandas as pd
images = pd.DataFrame(data['images'])
annotations = pd.DataFrame(data['annotations'])
categories = pd.DataFrame(data['categories'])

# %%
# Out:
# supercategory       food
# name             hot dog
# Name: 58, dtype: object

# %%
display(categories.head(5))
display(images.head(5))
display(annotations.head(5))
# Out:
#   supercategory  id        name
# 0        person   1      person
# 1       vehicle   2     bicycle
# 2       vehicle   3         car
# 3       vehicle   4  motorcycle
# 4       vehicle   5    airplane
#    license                      file_name  \
# 0        3  COCO_val2014_000000391895.jpg
# 1        4  COCO_val2014_000000522418.jpg
# 2        3  COCO_val2014_000000184613.jpg
# 3        3  COCO_val2014_000000318219.jpg
# 4        3  COCO_val2014_000000554625.jpg
#
#                                             coco_url  height  width  \
# 0  http://images.cocodataset.org/val2014/COCO_val...     360    640
# 1  http://images.cocodataset.org/val2014/COCO_val...     480    640
# 2  http://images.cocodataset.org/val2014/COCO_val...     336    500
# 3  http://images.cocodataset.org/val2014/COCO_val...     640    556
# 4  http://images.cocodataset.org/val2014/COCO_val...     640    426
#
#          date_captured                                         flickr_url  \
# 0  2013-11-14 11:18:45  http://farm9.staticflickr.com/8186/8119368305_...
# 1  2013-11-14 11:38:44  http://farm1.staticflickr.com/1/127244861_ab0c...
# 2  2013-11-14 12:36:29  http://farm3.staticflickr.com/2169/2118578392_...
# 3  2013-11-14 13:02:53  http://farm5.staticflickr.com/4125/5094763076_...
# 4  2013-11-14 16:03:19  http://farm5.staticflickr.com/4086/5094162993_...
#
#        id
# 0  391895
# 1  522418
# 2  184613
# 3  318219
# 4  554625
#                                         segmentation        area  iscrowd  \
# 0  [[239.97, 260.24, 222.04, 270.49, 199.84, 253....  2765.14865        0
# 1  [[247.71, 354.7, 253.49, 346.99, 276.63, 337.3...  1545.42130        0
# 2  [[274.58, 405.68, 298.32, 405.68, 302.45, 402....  5607.66135        0
# 3  [[296.65, 388.33, 296.65, 388.33, 297.68, 388....     0.00000        0
# 4  [[251.87, 356.13, 260.13, 343.74, 300.39, 335....   800.41325        0
#
#    image_id                             bbox  category_id    id
# 0    558840   [199.84, 200.46, 77.71, 70.88]           58   156
# 1    200365  [234.22, 317.11, 149.39, 38.55]           58   509
# 2    200365   [239.48, 347.87, 160.0, 57.81]           58   603
# 3    200365      [296.65, 388.33, 1.03, 0.0]           58   918
# 4    200365  [251.87, 333.42, 125.94, 22.71]           58  1072

# %%
merged_df = pd.merge(annotations, images, how="left", left_on="image_id", right_on="id")

# %%
merged_df2 = pd.merge(merged_df, categories, how="left", left_on="category_id", right_on="id")

# %%
merged_df2.head(2)
# Out:
#                                         segmentation        area  iscrowd  \
# 0  [[239.97, 260.24, 222.04, 270.49, 199.84, 253....  2765.14865        0
# 1  [[247.71, 354.7, 253.49, 346.99, 276.63, 337.3...  1545.42130        0
#
#    image_id                             bbox  category_id  id_x  license  \
# 0    558840   [199.84, 200.46, 77.71, 70.88]           58   156        1
# 1    200365  [234.22, 317.11, 149.39, 38.55]           58   509        3
#
#                        file_name  \
# 0  COCO_val2014_000000558840.jpg
# 1  COCO_val2014_000000200365.jpg
#
#                                             coco_url  height  width  \
# 0  http://images.cocodataset.org/val2014/COCO_val...     427    640
# 1  http://images.cocodataset.org/val2014/COCO_val...     480    640
#
#          date_captured                                         flickr_url  \
# 0  2013-11-15 06:55:40  http://farm5.staticflickr.com/4045/4488509035_...
# 1  2013-11-15 00:04:50  http://farm2.staticflickr.com/1177/1162747961_...
#
#      id_y supercategory  id     name
# 0  558840          food  58  hot dog
# 1  200365          food  58  hot dog

# %%
merged_df.dtypes
# Out:
# segmentation      object
# area             float64
# iscrowd            int64
# image_id           int64
# bbox              object
# category_id        int64
# id_x               int64
# license            int64
# file_name         object
# coco_url          object
# height             int64
# width              int64
# date_captured     object
# flickr_url        object
# id_y               int64
# dtype: object
